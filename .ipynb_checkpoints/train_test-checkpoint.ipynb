# %%
import numpy as np
import matplotlib.pyplot as plt
from architecture.Model import Model
from dataloader.Dataloader import *
from train.Trainer import *
import torch
from munch import Munch

# %%
#argparser doesnt work for jupyter notebook
params = Munch({
    'img_size': 256,
    'num_domains': 2,
    'latent_dim': 16,
    'hidden_dim': 512,
    'batch_size': 8,
    'style_dim': 64,
    'eval_iter': 50,
    'save_iter': 500,
    'lambda_ds': 1.0,
    'resume_iter': 0,
    'max_iter': 250,
    'mode': 'train',
    'lr': 1e-4,
    'f_lr': 1e-6,
    'beta1': 0.0,
    'beta2': 0.99,
    'weight_decay': 1e-2,
    'checkpoint_dir': '',
    'log_iter': 5,
    'epochs' : 20,
    'fan_pretrained_fname' : None#"architecture/FAN/weights.pth"
})

# %%
root = "../shared/stargan_folder/data/celeba_hq/train" #if gpu server
#Model,CopyModel = Model(params)

#restart gpu memory
#torch.cuda.empty_cache()

trainer = Trainer(params)

train_loader = get_loader(root, params.batch_size, params.img_size, num_files=2000)
loaders = Munch(train=train_loader)
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# Cell In[3], line 7
#       1 root = "../shared/stargan_folder/data/celeba_hq/train" #if gpu server
#       2 #Model,CopyModel = Model(params)
#       3
#       4 #restart gpu memory
#       5 #torch.cuda.empty_cache()
# ----> 7 trainer = Trainer(params)
#       9 train_loader = get_loader(root, params.batch_size, params.img_size, num_files=2000)
#      10 loaders = Munch(train=train_loader)
#
# File ~/StarGAN-v2/train/Trainer.py:41, in Trainer.__init__(self, params)
#      39 self.params = params
#      40 self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# ---> 41 self.networks, self.networks_copy = Model(params)
#      42 self.optimizers = Munch()
#      44 for key_network in ['generator', 'mapping_network', 'style_encoder', 'discriminator'] :
#
# File ~/StarGAN-v2/architecture/Model.py:49, in Model(params)
#      47 #ADD FAN NETWORK WITH PRETRAINED WEIGHTS
#      48 if params.num_domains==2 : #only if celeba_hq
# ---> 49     fan = FAN(pretrained_file=params.fan_pretrained_fname).eval().to(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
#      50     #fan.get_heatmap = fan.module.get_heatmap
#      51     networks.fan = fan
#
# File ~/StarGAN-v2/architecture/FAN/models.py:195, in FAN.__init__(self, num_modules, end_relu, num_landmarks, pretrained_file)
#     193 #load pretrained model
#     194 if pretrained_file != None:
# --> 195     self.load_state_dict(torch.load(pretrained_file))
#
# File /usr/local/lib/python3.10/dist-packages/torch/serialization.py:795, in load(f, map_location, pickle_module, weights_only, **pickle_load_args)
#     793     except RuntimeError as e:
#     794         raise pickle.UnpicklingError(UNSAFE_MESSAGE + str(e)) from None
# --> 795 return _legacy_load(opened_file, map_location, pickle_module, **pickle_load_args)
#
# File /usr/local/lib/python3.10/dist-packages/torch/serialization.py:1002, in _legacy_load(f, map_location, pickle_module, **pickle_load_args)
#     996 if not hasattr(f, 'readinto') and (3, 8, 0) <= sys.version_info < (3, 8, 2):
#     997     raise RuntimeError(
#     998         "torch.load does not work with file-like objects that do not implement readinto on Python 3.8.0 and 3.8.1. "
#     999         f"Received object of type \"{type(f)}\". Please update to Python 3.8.2 or newer to restore this "
#    1000         "functionality.")
# -> 1002 magic_number = pickle_module.load(f, **pickle_load_args)
#    1003 if magic_number != MAGIC_NUMBER:
#    1004     raise RuntimeError("Invalid magic number; corrupt file?")
#
# UnpicklingError: invalid load key, '<'.

# %%
trainer.train(loaders)
# Out:
# Time elapsed : 1:13:53.120030
# Epoch : 9/20, Batch 250/250
# D/latent_real: [0.6112] D/latent_fake: [0.7390] D/latent_reg: [0.0000] D/ref_real: [0.6360] D/ref_fake: [0.6802] D/ref_reg: [0.0000] G/latent_adv: [0.7790] G/latent_sty: [0.3569] G/latent_ds: [0.4143] G/latent_cyc: [0.3640] G/ref_adv: [0.7022] G/ref_sty: [0.0000] G/ref_ds: [0.0000] G/ref_cyc: [0.3220] G/lambda_ds: [0.5000]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 trainer.train(loaders)
#
# File ~/StarGAN-v2/train/Trainer.py:169, in Trainer.train(self, loaders)
#     166 losses.g_ref.append(g_loss.cpu().detach().numpy())
#     168 self._reset_grad()
# --> 169 g_loss.backward()
#     170 optims.generator.step()
#     171 optims.mapping_network.step()
#
# File /usr/local/lib/python3.10/dist-packages/torch/_tensor.py:487, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     477 if has_torch_function_unary(self):
#     478     return handle_torch_function(
#     479         Tensor.backward,
#     480         (self,),
#    (...)
#     485         inputs=inputs,
#     486     )
# --> 487 torch.autograd.backward(
#     488     self, gradient, retain_graph, create_graph, inputs=inputs
#     489 )
#
# File /usr/local/lib/python3.10/dist-packages/torch/autograd/__init__.py:197, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     192     retain_graph = create_graph
#     194 # The reason we repeat same the comment below is that
#     195 # some Python versions print out the first line of a multi-line function
#     196 # calls in the traceback and some print out the last line
# --> 197 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     198     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     199     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %%
from torchvision.utils import make_grid

# %%
generator = trainer.networks.generator
mn = trainer.networks.mapping_network

train_fetcher=Fetcher(train_loader)
inputs = next(train_fetcher)
x_org,y_org = inputs.x, inputs.y
z1, z2 = inputs.z1, inputs.z2
x_ref1, x_ref2 = inputs.x_ref1, inputs.x_ref2
y_trg = inputs.y_trg

style = mn(z1,y_trg)
input_img=x_org

x_fake=generator(input_img,style)

x_n = [(x-x.min())/(x.max()-x.min()) for x in x_fake]
#normalize_tensor(x_fake)

grid = make_grid(x_n)



imgs=torch.permute(grid, [1,2,0]).cpu().detach().numpy()

#fake_img=torch.permute((x_fake+1)/2, [1,2,0]).cpu().detach().numpy()

plt.figure(figsize=(10,5))
plt.imshow(imgs)
plt.show()

# %%
x_n = [(x-x.min())/(x.max()-x.min()) for x in x_fake]

#x_n = (x-x.min())/(x.max()-x.min())

x_n.max()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 x_n = np.array([(x-x.min())/(x.max()-x.min()) for x in x_fake])
#       3 #x_n = (x-x.min())/(x.max()-x.min())
#       5 x_n.max()
#
# File /usr/local/lib/python3.10/dist-packages/torch/_tensor.py:955, in Tensor.__array__(self, dtype)
#     953     return handle_torch_function(Tensor.__array__, (self,), self, dtype=dtype)
#     954 if dtype is None:
# --> 955     return self.numpy()
#     956 else:
#     957     return self.numpy().astype(dtype, copy=False)
#
# TypeError: can't convert cuda:0 device type tensor to numpy. Use Tensor.cpu() to copy the tensor to host memory first.

# %%
#continue training from last iter = 1000
params.resume_iter=1000
params.max_iter=2000
params.lambda_ds=0.5 #
params

trainer=Trainer(params)
trainer.train(loaders)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 8
#       5 params
#       7 trainer=Trainer(params)
# ----> 8 trainer.train(loaders)
#
# File ~/StarGAN-v2/train/Trainer.py:297, in Trainer.train(self, loaders)
#     294 optims.mapping_network.step()
#     295 optims.style_encoder.step()
# --> 297 g_loss, g_loss_ref = loss_generator(nets, x_org, y_org, y_trg,
#     298                                         x_refs=[x_ref1,x_ref2],
#     299                                         lambda_ds=params.lambda_ds)
#     300 losses.g_ref.append(g_loss.cpu().detach().numpy())
#     302 self._reset_grad()
#
# File ~/StarGAN-v2/train/loss.py:92, in loss_generator(nets, x_real, y_org, y_trg, z_trgs, x_refs, lambda_sty, lambda_ds, lambda_cyc)
#      90 elif x_refs is not None:
#      91     x_ref, x_ref2 = x_refs
# ---> 92     s_trg = nets.style_encoder(x_ref, y_trg)
#      93     s_trg2 = nets.style_encoder(x_ref2, y_trg)
#      94 else:
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/StarGAN-v2/architecture/Style_Encoder.py:38, in StyleEncoder.forward(self, x, branch)
#      36 # Generate output for different branches in parallel
#      37 outp = torch.stack([linear(x) for linear in self.parallel], dim=1)
# ---> 38 s = outp[torch.arange(branch.size(0)).to(branch.device), branch] # to(branch.device) to avoid Runtime error
#      39 return s
#
# KeyboardInterrupt:

# %%
generator = trainer.networks_copy.generator
mn = trainer.networks_copy.mapping_network

train_fetcher=Fetcher(train_loader)
inputs = next(train_fetcher)
x_org,y_org = inputs.x, inputs.y
z1, z2 = inputs.z1, inputs.z2
x_ref1, x_ref2 = inputs.x_ref1, inputs.x_ref2
y_trg = inputs.y_trg

style = mn(z1,y_trg)
input_img=x_org

x_fake=generator(input_img,style)[0]

fake_img=torch.permute((x_fake+1)/2, [1,2,0]).cpu().detach().numpy()

plt.imshow(fake_img)
plt.show()
